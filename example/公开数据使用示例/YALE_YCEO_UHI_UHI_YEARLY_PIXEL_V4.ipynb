# %% [markdown]
# # YCEO SUHI : Pixel-Level Annual Daytime and Nighttime Intensity 简介与Notebook示例
#
# YCEO Surface Urban Heat Islands 数据集包括了全世界超10000个城市群的年度、夏季和冬季，白天与夜晚地表热岛强度指数（SUHI）数据。该数据集使用了MODIS 8天Terra和Aqua地表温度（LST）产品、Landscan城市分布数据集、2010年全球多分辨率地形数据和欧洲航天局（ESA）气候变化倡议（CCI）的土地覆盖数据。该产品空间分辨率为300米。
#
# 本数据集为UHI_yearly_pixel：2003-2018年白天与夜晚SUHI强度的空间分布产品（空间辨率为300米）。

# %% [markdown]
# ## 数据集检索

# %%
import aie
aie.Authenticate()
aie.Initialize()


#指定检索数据集
dataset = aie.ImageCollection('YALE_YCEO_UHI_UHI_YEARLY_PIXEL_V4')
                
imgs = dataset.select(['Daytime']);

map = aie.Map(
    center=[121.02,31.17],
    height=800,
    zoom=8
)
vis_params = {
    'bands': 'Daytime',
    'min': -1.5,
    'max': 7.5,
    'palette': [
       "#313695","#74add1","#fed976","#feb24c","#fd8d3c",
        "#fc4e2a", "#e31a1c","#b10026",
    ]
}
map.addLayer(
    imgs,
    vis_params,
    'Daytime UHI',
    bounds=imgs.getBounds()
)
map

# %% [markdown]
# ## 单景影像检索

# %%
import aie
aie.Authenticate()
aie.Initialize()

img = aie.Image('YALE_YCEO_UHI_UHI_YEARLY_PIXEL_V4_2003')

map = aie.Map(
    center=[121.02,31.17],
    height=800,
    zoom=8
)
vis_params = {
    'bands': 'Daytime',
    'min': -1.5,
    'max': 7.5,
    'palette': [
       "#313695","#74add1","#fed976","#feb24c","#fd8d3c",
        "#fc4e2a", "#e31a1c","#b10026",
    ]
}

map.addLayer(
    img,
    vis_params,
    'Daytime UHI',
    bounds=img.getBounds()
)
map
