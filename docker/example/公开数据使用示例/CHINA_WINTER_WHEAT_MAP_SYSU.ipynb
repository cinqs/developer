# %% [markdown]
# # 2016-2020年中国冬小麦种植分布数据集（袁文平教授团队）简介与Notebook示例
# 本数据集用基于时间权重的动态时间规划方法，通过比较已知冬小麦田块和未知地物类型的季节变化曲线的相似程度，得出了 2016–2020 年全国 11 个省（种植面积占全国冬小麦面积的99%以上） 30 米空间分辨率的冬小麦种植面积。经过野外调查样本的验证，冬小麦识别总体精度达到 89.88%，生产者精度和用户精度分别为 89.30%和 90.59%。数据覆盖省份包括：河北省、河南省、山东省、安徽省、江苏省、湖北省、陕西省、山西省、甘肃省、四川省、新疆维吾尔自治区。
#
# ## 数据集检索

# %%
import aie
aie.Authenticate()
aie.Initialize()


feature_collection = aie.FeatureCollection('China_Province') \
                        .filter(aie.Filter.eq('province', '陕西省'))

geometry = feature_collection.geometry()

dataset = aie.ImageCollection('CHINA_WINTER_WHEAT_MAP_SYSU') \
             .filterBounds(geometry) \
             .limit(1)

map = aie.Map(
    center=dataset.getCenter(),
    height=800,
    zoom=6
)

vis_params = {
    'bands': ['Map'],
    'min': 0,
    'max': 1,
    "palette":["#d9d9d9","#ff0000"]
}

map.addLayer(
    dataset,
    vis_params,
    'CHINA_WINTER_WHEAT_MAP_SYSU',
    bounds=dataset.getBounds()
)
map

# %% [markdown]
# ## 单景影像检索

# %%
import aie
aie.Authenticate()
aie.Initialize()

img = aie.Image('CHINA_WINTER_WHEAT_MAP_SYSU_2019_N33E105')

map = aie.Map(
    center=img.getCenter(),
    height=800,
    zoom=6
)

vis_params = {
    'bands': ['Map'],
    'min': 0,
    'max': 1,
    "palette":["#d9d9d9","#ff0000"]
}

map.addLayer(
    img,
    vis_params,
    'CHINA_WINTER_WHEAT_MAP_SYSU',
    bounds=img.getBounds()
)
map
