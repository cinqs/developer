# %% [markdown]
# # AI Earth中国风机分布数据集(AIE_WindTurbine)简介
#
# 数据集为AI Earth团队基于已发布在平台的的风机识别AI算法，对公开的高分辨率卫星底图，实现全国区域风机位置提取。风机识别算法采用检测模型VFNet，配合swin transformer 生成 backbone，对AI Earth团队自有风机样本进行训练，在测试集中整体准召达双90%。
#
# 此数据集为AI Earth团队在大范围地物提取方向的测试产品。用户在浏览或使用过程中存在的漏检、误检敬请谅解。
