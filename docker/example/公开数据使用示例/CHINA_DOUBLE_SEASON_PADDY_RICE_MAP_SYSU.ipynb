# %% [markdown]
# # 2016-2020年中国双季稻种植分布数据集（袁文平教授团队）简介与Notebook示例
# 本数据集是基于Sentinel-1遥感数据，利用基于物候特征识别方法制作的全国10米分辨率的双季稻种植位置数据集。具体而言，该数据集基于合成孔径雷达（SAR）数据，使用基于时间权重的动态时间规划法，结合省级水稻统计面积，生成了2016-2020年中国南方9个省份（种植面积占全国99%以上）的双季稻种植面积分布图，空间分辨率为10米。基于145210个实地调查样本和县级统计数据，对该数据集精度进行验证。基于实地调查样本进行像元尺度验证，9个省的早稻识别总体精度从88.07%到95.97%；9个省的晚稻识别总体精度从88.25%到95.68%。基于县级统计面积进行区域尺度验证，对于早稻而言，各省四年平均决定系数（R2）的范围从0.50到0.87，均方根误差（RMSE）的范围从1.53到6.94，相对误差（RMAE）的范围从22%到59%。晚稻的区域尺度验证精度和早稻类似。数据覆盖省份包括：安徽省、福建省、广东省、广西壮族自治区、海南省、湖北省、湖南省、江西省、浙江省。
#
# ## 数据集检索

# %%
import aie
aie.Authenticate()
aie.Initialize()


dataset = aie.ImageCollection('CHINA_DOUBLE_SEASON_PADDY_RICE_MAP_SYSU') \
             .limit(1)

map = aie.Map(
    center=dataset.getCenter(),
    height=800,
    zoom=6
)

vis_params = {
    'bands': ['ER'],
    'min': 0,
    'max': 1,
    "palette":["#d9d9d9","#ff0000"]
}

map.addLayer(
    dataset,
    vis_params,
    'CHINA_DOUBLE_SEASON_PADDY_RICE_MAP_SYSU',
    bounds=dataset.getBounds()
)
map

# %% [markdown]
# ## 单景影像检索
# ### 早稻

# %%
import aie
aie.Authenticate()
aie.Initialize()

img = aie.Image('CHINA_DOUBLE_SEASON_PADDY_RICE_MAP_SYSU_2016_N24E117')

map = aie.Map(
    center=img.getCenter(),
    height=800,
    zoom=6
)

vis_params = {
    'bands': ['ER'],
    'min': 0,
    'max': 1,
    "palette":["#d9d9d9","#ff0000"]
}

map.addLayer(
    img,
    vis_params,
    'CHINA_DOUBLE_SEASON_PADDY_RICE_MAP_SYSU',
    bounds=img.getBounds()
)
map

# %% [markdown]
# ### 晚稻

# %%
import aie
aie.Authenticate()
aie.Initialize()

img = aie.Image('CHINA_DOUBLE_SEASON_PADDY_RICE_MAP_SYSU_2016_N24E117')

map = aie.Map(
    center=img.getCenter(),
    height=800,
    zoom=6
)

vis_params = {
    'bands': ['LR'],
    'min': 0,
    'max': 1,
    "palette":["#d9d9d9","#008000"]
}

map.addLayer(
    img,
    vis_params,
    'CHINA_DOUBLE_SEASON_PADDY_RICE_MAP_SYSU',
    bounds=img.getBounds()
)
map
