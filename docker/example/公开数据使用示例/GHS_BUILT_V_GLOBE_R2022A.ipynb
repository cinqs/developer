# %% [markdown]
# # GHS Built-up Volume Grid简介与Notebook示例
# GHS Built-up Volume Grid数据集由GHS-BUILT-S-R2022A和GHS-BUILT-H-R2022A衍生而来，时序包括1975-2030年，在1975年至2020年为估计值并以5年为间隔，2025年和2030年由3种方式（LIN、PLY、MED）进行趋势推演而来的预测值。数据集描述了建筑体积的分布，单位为立方米。数据记录了总建成量和分配给主要非住宅（NRES）用途的建成量。具体信息可查阅<a href="https://ghsl.jrc.ec.europa.eu/ghs_buV2022.php" target="_blank">https://ghsl.jrc.ec.europa.eu/ghs_buV2022.php</a>
#
# ## 数据集检索

# %%
import aie
aie.Authenticate()
aie.Initialize()

# 指定需要检索的区域
feature_collection = aie.FeatureCollection('China_Province') \
                        .filter(aie.Filter.eq('province', '浙江省'))

geometry = feature_collection.geometry()


dataset = aie.ImageCollection('GHS_BUILT_V_GLOBE_R2022A') \
             .filterBounds(geometry) \
             .limit(10);

map = aie.Map(
    center=dataset.getCenter(),
    height=800,
    zoom=4
)

vis_params = {
    'bands': ['volume'],
    'min': 0,
    'max': 100000,
    "palette":["#1A1384","#BB5079","#F1F375"]
}

map.addLayer(
    dataset,
    vis_params,
    'GHS Built-up Volume Grid',
    bounds=dataset.getBounds()
)
map

# %% [markdown]
# ## 单景影像检索

# %%
import aie
aie.Authenticate()
aie.Initialize()

img = aie.Image('GHS_BUILT_V_E1975_GLOBE_R2022A_54009_100_V1_0_R10_C1')

map = aie.Map(
    center=img.getCenter(),
    height=800,
    zoom=4
)

vis_params = {
    'bands': ['volume'],
    'min': 0,
    'max': 100000,
    "palette":["#1A1384","#BB5079","#F1F375"]
}

map.addLayer(
    img,
    vis_params,
    'GHS Built-up Volume Grid',
    bounds=img.getBounds()
)
map
